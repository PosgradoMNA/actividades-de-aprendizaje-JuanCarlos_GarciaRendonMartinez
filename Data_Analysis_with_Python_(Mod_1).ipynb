# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-JuanCarlos_GarciaRendonMartinez/blob/main/Data_Analysis_with_Python_(Mod_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nombre**: Juan Carlos Garcia Rendon Martinez
#
# **Matrícula**: A01793708
#
# **Materia**: Ciencia y Analitica de Datos
#
# **Profesor**: Bernardo Charles Canales
#
# **Fecha**: 11/10/2022

# %% [markdown]
# # Python Packages for Data Science 2:28
#
# Usaremos Pandas, Numpy, SciPy, Matplotlib, Seaborn, Scikit-learn y Statsmodels

# %% [markdown]
# # Importing and Exporting Data in Python 4:13
# Para leer formatos en Python hay que considerar:
#
#   1) formato:  csv, json, xlsx, etc
#   2) Path: Donde se encuentra la información, internet o local
#
# Para importar un CSV *Pandas considera que tiene headers el csv
#
# ```
# import pandas as pd
# df=read_csv("nombre.csv", header = None)
# df          #imprime todo
# df.head(n)  #imprime los primeros n
# df.tail(n)  #imprime los ultimos n
#
# se pueden asignar los nombres a las columnas en caso de no tenerlos. Solo hay que hacer una lista y asignarla a df.columns
# ```
# Para guardar de nuevo el archivo se puede hacer:
#
# ```
# df.to_csv(path)
# ```

# %% [markdown]
# # Getting Started Analyzing Data in Python 4:14
#
# En general usaremos pandas, que utiliza:
# objects:  strings
#
# int64:    int
#
# float64:   numeric with decimals
#
# datetime:  Fechas
#
# *Siempre hay que revisar los tipos de dato para saber qué métodos se pueden usar y evitar errores
#
# Para saber como se distribuye la información podemos usar:
#
#
# ```
# df.describe()  #Regresa cuenta, media, desviacion, minimo, maximo y cuartiles
# df.describe(include="all")    #Hace que también regrese datos categóricos (strings)
# df.info()   #Regresa el top 30 y bottom 30
# ```

# %% [markdown]
# # Lab 1: Introducción

# %%
##Lab 1:Introduction
import pandas as pd
import numpy as np

path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
df = pd.read_csv(path, header=None)

df.head(5)

#1. Check the bottom 10 rows of data frame "df".
df.tail(10)

#Nombrar las columnas
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

df.columns = headers
df.head(10)

df1=df.replace('?',np.NaN)   #Remplazar signos

df=df1.dropna(subset=["price"], axis=0)
df.head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2               NaN         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1               NaN         audi       gas        std
# 8           1               158         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# 13          0               188          bmw       gas        std
# ...

# %%
#2. Find the name of the columns of the dataframe.
print(df.columns)

df.to_csv("automobile.csv", index=False)
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
from numpy.lib.shape_base import column_stack
print(df.dtypes)   #Dice que tipo de dato tiene cada columna
df.describe()       #Estadisticas de las columnas numericas
df.describe(include="all")       #Estadisticas de todas las columnas

#3. Selecciona las columnas
df[["length", "compression-ratio"]].describe()
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object
#            length  compression-ratio
# count  201.000000         201.000000
# mean   174.200995          10.164279
# std     12.322175           4.004965
# ...

# %% [markdown]
# # Graded Review Questions

# %%
#1. What does CSV stand for?  
 #  Comma separeted values

#2. In the data set, which of the following represents an attribute or feature?
 #  Columnas

#3. What is the name of what we want to predict?
 # Target

#4. What is the command to display the first five rows of a dataframe df?
 # df.head()}

#5. What command do you use to get the data type of each row of the dataframe df?
 # df.dtypes

#6. How do you get a statistical summary of a dataframe df?
 # df.describe()

#7. If you use the method describe() without changing any of the arguments, you will get a statistical summary of all the columns of type "object".
 # False

# %% [markdown]
# ![image.png](data:image/png;base64,...)
